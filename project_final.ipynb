# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
project_dir = '/content/drive/MyDrive/analytical_tools_project/project/'

# %%
df = pd.read_excel(project_dir + "dataset.xlsx")
df
# Out:
#       Longitude   Latitude Station Name  Climate ID            Date_Time  \
# 0         -82.96     42.28      WINDSOR     6139525  2013-01-01 00:00:00
# 1         -82.96     42.28      WINDSOR     6139525  2013-02-01 00:00:00
# 2         -82.96     42.28      WINDSOR     6139525  2013-03-01 00:00:00
# 3         -82.96     42.28      WINDSOR     6139525  2013-04-01 00:00:00
# 4         -82.96     42.28      WINDSOR     6139525  2013-05-01 00:00:00
# ...          ...       ...          ...         ...                  ...
# 3647      -82.96     42.28      WINDSOR     6139530           12/27/2022
# 3648      -82.96     42.28      WINDSOR     6139530           12/28/2022
# 3649      -82.96     42.28      WINDSOR     6139530           12/29/2022
# 3650      -82.96     42.28      WINDSOR     6139530           12/30/2022
# 3651      -82.96     42.28      WINDSOR     6139530           12/31/2022
#
#       Year  Month  Day  Max Temp   Min Temp   Mean Temp   Heat Deg Days   \
# ...

# %%
df.head(16)
# Out:
#     Longitude   Latitude Station Name  Climate ID            Date_Time  Year  \
# 0       -82.96     42.28      WINDSOR     6139525  2013-01-01 00:00:00  2013
# 1       -82.96     42.28      WINDSOR     6139525  2013-02-01 00:00:00  2013
# 2       -82.96     42.28      WINDSOR     6139525  2013-03-01 00:00:00  2013
# 3       -82.96     42.28      WINDSOR     6139525  2013-04-01 00:00:00  2013
# 4       -82.96     42.28      WINDSOR     6139525  2013-05-01 00:00:00  2013
# 5       -82.96     42.28      WINDSOR     6139525  2013-06-01 00:00:00  2013
# 6       -82.96     42.28      WINDSOR     6139525  2013-07-01 00:00:00  2013
# 7       -82.96     42.28      WINDSOR     6139525  2013-08-01 00:00:00  2013
# 8       -82.96     42.28      WINDSOR     6139525  2013-09-01 00:00:00  2013
# 9       -82.96     42.28      WINDSOR     6139525  2013-10-01 00:00:00  2013
# 10      -82.96     42.28      WINDSOR     6139525  2013-11-01 00:00:00  2013
# ...

# %%
df.tail()
# Out:
#       Longitude   Latitude Station Name  Climate ID   Date_Time  Year  Month  \
# 3647      -82.96     42.28      WINDSOR     6139530  12/27/2022  2022     12
# 3648      -82.96     42.28      WINDSOR     6139530  12/28/2022  2022     12
# 3649      -82.96     42.28      WINDSOR     6139530  12/29/2022  2022     12
# 3650      -82.96     42.28      WINDSOR     6139530  12/30/2022  2022     12
# 3651      -82.96     42.28      WINDSOR     6139530  12/31/2022  2022     12
#
#       Day  Max Temp   Min Temp   Mean Temp   Heat Deg Days   Cool Deg Days   \
# 3647   27       1.00      -7.00       -3.00           21.00            0.00
# 3648   28       5.50      -4.00        0.80           17.20            0.00
# 3649   29      12.00       2.50        7.30           10.70            0.00
# 3650   30      12.50       8.50       10.50            7.50            0.00
# 3651   31       6.50       5.00        5.80           12.20            0.00
#
# ...

# %%
df.sample(10)
# Out:
#       Longitude   Latitude Station Name  Climate ID            Date_Time  \
# 883       -82.93     42.33      WINDSOR     6139520  2015-03-06 00:00:00
# 3262      -82.96     42.28      WINDSOR     6139530  2021-07-12 00:00:00
# 103       -82.96     42.28      WINDSOR     6139525            4/14/2013
# 622       -82.96     42.28      WINDSOR     6139525            9/15/2014
# 3360      -82.96     42.28      WINDSOR     6139530            3/15/2022
# 3245      -82.96     42.28      WINDSOR     6139530           11/20/2021
# 547       -82.96     42.28      WINDSOR     6139525  2014-02-07 00:00:00
# 770       -82.93     42.33      WINDSOR     6139520  2015-10-02 00:00:00
# 3258      -82.96     42.28      WINDSOR     6139530  2021-03-12 00:00:00
# 1385      -82.93     42.33      WINDSOR     6139520           10/17/2016
#
#       Year  Month  Day  Max Temp   Min Temp   Mean Temp   Heat Deg Days   \
# 883   2015      6    3      22.00      10.00       16.00            2.00
# ...

# %%
df.shape
# Out:
# (3652, 19)

# %%
df.describe()
# Out:
#        Longitude   Latitude   Climate ID     Year    Month      Day  \
# count    3,652.00  3,652.00     3,652.00 3,652.00 3,652.00 3,652.00
# mean       -82.95     42.30 6,139,525.75 2,017.50     6.52    15.73
# std          0.01      0.02         4.21     2.87     3.45     8.80
# min        -82.96     42.28 6,139,520.00 2,013.00     1.00     1.00
# 25%        -82.96     42.28 6,139,520.00 2,015.00     4.00     8.00
# 50%        -82.96     42.28 6,139,526.00 2,017.50     7.00    16.00
# 75%        -82.93     42.33 6,139,530.00 2,020.00    10.00    23.00
# max        -82.93     42.33 6,139,530.00 2,022.00    12.00    31.00
#
#        Max Temp   Min Temp   Mean Temp   Heat Deg Days   Cool Deg Days   \
# count   3,603.00   3,596.00    3,593.00        3,593.00        3,640.00
# mean       15.34       6.05       10.69            8.87            1.65
# std        11.58      10.17       10.72            8.94            2.84
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.describe()
# Out:
#        Longitude   Latitude   Climate ID     Year    Month      Day  \
# count    3,652.00  3,652.00     3,652.00 3,652.00 3,652.00 3,652.00
# mean       -82.95     42.30 6,139,525.75 2,017.50     6.52    15.73
# std          0.01      0.02         4.21     2.87     3.45     8.80
# min        -82.96     42.28 6,139,520.00 2,013.00     1.00     1.00
# 25%        -82.96     42.28 6,139,520.00 2,015.00     4.00     8.00
# 50%        -82.96     42.28 6,139,526.00 2,017.50     7.00    16.00
# 75%        -82.93     42.33 6,139,530.00 2,020.00    10.00    23.00
# max        -82.93     42.33 6,139,530.00 2,022.00    12.00    31.00
#
#        Max Temp   Min Temp   Mean Temp   Heat Deg Days   Cool Deg Days   \
# count   3,603.00   3,596.00    3,593.00        3,593.00        3,640.00
# mean       15.34       6.05       10.69            8.87            1.65
# std        11.58      10.17       10.72            8.94            2.84
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Longitude        3652 non-null   float64
#  1   Latitude         3652 non-null   float64
#  2   Station Name     3652 non-null   object
#  3   Climate ID       3652 non-null   int64
#  4   Date_Time        3652 non-null   object
#  5   Year             3652 non-null   int64
#  6   Month            3652 non-null   int64
#  7   Day              3652 non-null   int64
#  8   Max Temp         3603 non-null   float64
#  9   Min Temp         3596 non-null   float64
#  10  Mean Temp        3593 non-null   float64
#  11  Heat Deg Days    3593 non-null   float64
#  12  Cool Deg Days    3640 non-null   float64
#  13  Total Rain       3640 non-null   float64
#  14  Total Snow       3640 non-null   float64
#  15  Total Precip     3640 non-null   float64
# ...

# %%
df.describe(include = "all") 
#The include parameter is used to specify which types of columns to include in the output. In this case, include="all" is used to include all columns in the output, regardless of their data type.
# Out:
#         Longitude   Latitude Station Name   Climate ID            Date_Time  \
# count     3,652.00  3,652.00         3652     3,652.00                 3652
# unique         NaN       NaN            1          NaN                 3652
# top            NaN       NaN      WINDSOR          NaN  2013-01-01 00:00:00
# freq           NaN       NaN         3652          NaN                    1
# mean        -82.95     42.30          NaN 6,139,525.75                  NaN
# std           0.01      0.02          NaN         4.21                  NaN
# min         -82.96     42.28          NaN 6,139,520.00                  NaN
# 25%         -82.96     42.28          NaN 6,139,520.00                  NaN
# 50%         -82.96     42.28          NaN 6,139,526.00                  NaN
# 75%         -82.93     42.33          NaN 6,139,530.00                  NaN
# max         -82.93     42.33          NaN 6,139,530.00                  NaN
#
# ...

# %%
# check for duplicates
df.duplicated().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Longitude ', 'Latitude', 'Station Name', 'Climate ID', 'Date_Time',
#        'Year', 'Month', 'Day', 'Max Temp ', 'Min Temp ', 'Mean Temp ',
#        'Heat Deg Days ', 'Cool Deg Days ', 'Total Rain ', 'Total Snow ',
#        'Total Precip ', 'Snow on Grnd ', 'Dir of Max Gust', 'Spd of Max Gust'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Longitude             0
# Latitude              0
# Station Name          0
# Climate ID            0
# Date_Time             0
# Year                  0
# Month                 0
# Day                   0
# Max Temp             49
# Min Temp             56
# Mean Temp            59
# Heat Deg Days        59
# Cool Deg Days        12
# Total Rain           12
# Total Snow           12
# Total Precip         12
# Snow on Grnd         13
# Dir of Max Gust    1005
# Spd of Max Gust     531
# dtype: int64

# %%
def FindMissingColsPercentage(df):

    total = 0
    for col in df.columns:
        missing_vals = df[col].isnull().sum()
        # mean = sum / total
        pct = df[col].isnull().mean() * 100 
        if missing_vals != 0:
          print('{} => {} [{}%]'.format(col, df[col].isnull().sum(), round(pct, 2)))
        total += missing_vals
    
    if total == 0:
        print("no missing values")

# %%
FindMissingColsPercentage(df)
# Out:
# Max Temp  => 49 [1.34%]
# Min Temp  => 56 [1.53%]
# Mean Temp  => 59 [1.62%]
# Heat Deg Days  => 59 [1.62%]
# Cool Deg Days  => 12 [0.33%]
# Total Rain  => 12 [0.33%]
# Total Snow  => 12 [0.33%]
# Total Precip  => 12 [0.33%]
# Snow on Grnd  => 13 [0.36%]
# Dir of Max Gust => 1005 [27.52%]
# Spd of Max Gust => 531 [14.54%]

# %%
df.shape
# Out:
# (3652, 19)

# %%
df.columns
# Out:
# Index(['Longitude ', 'Latitude', 'Station Name', 'Climate ID', 'Date_Time',
#        'Year', 'Month', 'Day', 'Max Temp ', 'Min Temp ', 'Mean Temp ',
#        'Heat Deg Days ', 'Cool Deg Days ', 'Total Rain ', 'Total Snow ',
#        'Total Precip ', 'Snow on Grnd ', 'Dir of Max Gust', 'Spd of Max Gust'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', "_")

# %%
df.columns
# Out:
# Index(['Longitude_', 'Latitude', 'Station_Name', 'Climate_ID', 'Date_Time',
#        'Year', 'Month', 'Day', 'Max_Temp_', 'Min_Temp_', 'Mean_Temp_',
#        'Heat_Deg_Days_', 'Cool_Deg_Days_', 'Total_Rain_', 'Total_Snow_',
#        'Total_Precip_', 'Snow_on_Grnd_', 'Dir_of_Max_Gust', 'Spd_of_Max_Gust'],
#       dtype='object')

# %%
df.Date_Time
# Out:
# 0       2013-01-01 00:00:00
# 1       2013-02-01 00:00:00
# 2       2013-03-01 00:00:00
# 3       2013-04-01 00:00:00
# 4       2013-05-01 00:00:00
#                ...
# 3647             12/27/2022
# 3648             12/28/2022
# 3649             12/29/2022
# 3650             12/30/2022
# 3651             12/31/2022
# Name: Date_Time, Length: 3652, dtype: object

# %%
df.fillna(0, inplace=True)

# %%
df.Total_Rain_.unique() #This data shows that we have an outlier that is nan
# Out:
# array([  0. ,   0.2,   0.4,   6.8,   2.8,  27.2,   1.6,  15. ,  10.4,
#          2. ,   0.6,   1. ,   3.6,  17.2,   9.8,   1.2,   1.4,   3.4,
#         10.8,  39.4,   8.4,   0.8,  10.2,  11.2,  13. ,   7. ,  13.4,
#          3. ,  14.6,   4.6,   1.8,  19.4,  16.4,   9. ,  10. ,  23. ,
#         47.2,   4.4,  16.2,  16.6,  11.8,  24.2,   5.2,  31.2,  57. ,
#         14.2,  32.6,   4.8,  19.2,   5.4,   5.6,  35. ,  12.6,  13.6,
#         28.2,   6. ,   8. ,   2.2,  40.8,   7.4,   4. ,   3.2,  15.6,
#          9.6,   3.8,  34.8,   6.6,   5.8,  16.9,   2.6,   8.2,  12.2,
#          9.2,  24.4,  12.4,   7.6,  22.4,  58.2,  56.4,   7.8,   6.2,
#          4.2,  46.8,  73.6,  11.4,   7.2,  14.4,  25.8,  64.8,  17. ,
#          0.3,   6.4,  23.5,   0.5,   1.3,  17.9,   5.1,   2.7,  10.6,
#         12.5,  14.9,   1.5,   8.7,   2.1,  42.8,   9.4,   5. ,   0.7,
#         21.4,  23.2,  33. ,   5.3,  14. ,  19.1,  32.4,  19.6,  27.4,
# ...

# %%
df.loc[df["Total_Rain_"]==0]
# Out:
#       Longitude_  Latitude Station_Name  Climate_ID            Date_Time  \
# 0         -82.96     42.28      WINDSOR     6139525  2013-01-01 00:00:00
# 1         -82.96     42.28      WINDSOR     6139525  2013-02-01 00:00:00
# 2         -82.96     42.28      WINDSOR     6139525  2013-03-01 00:00:00
# 3         -82.96     42.28      WINDSOR     6139525  2013-04-01 00:00:00
# 4         -82.96     42.28      WINDSOR     6139525  2013-05-01 00:00:00
# ...          ...       ...          ...         ...                  ...
# 3644      -82.96     42.28      WINDSOR     6139530           12/24/2022
# 3645      -82.96     42.28      WINDSOR     6139530           12/25/2022
# 3646      -82.96     42.28      WINDSOR     6139530           12/26/2022
# 3647      -82.96     42.28      WINDSOR     6139530           12/27/2022
# 3648      -82.96     42.28      WINDSOR     6139530           12/28/2022
#
#       Year  Month  Day  Max_Temp_  Min_Temp_  Mean_Temp_  Heat_Deg_Days_  \
# ...

# %%
df = df.replace(0, np.nan)
df = df.fillna(df.mean())
# Out:
# <ipython-input-63-f2dbef666726>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(df.mean())

# %%
df.Total_Rain_.unique()
# Out:
# array([  7.35258481,   0.2       ,   0.4       ,   6.8       ,
#          2.8       ,  27.2       ,   1.6       ,  15.        ,
#         10.4       ,   2.        ,   0.6       ,   1.        ,
#          3.6       ,  17.2       ,   9.8       ,   1.2       ,
#          1.4       ,   3.4       ,  10.8       ,  39.4       ,
#          8.4       ,   0.8       ,  10.2       ,  11.2       ,
#         13.        ,   7.        ,  13.4       ,   3.        ,
#         14.6       ,   4.6       ,   1.8       ,  19.4       ,
#         16.4       ,   9.        ,  10.        ,  23.        ,
#         47.2       ,   4.4       ,  16.2       ,  16.6       ,
#         11.8       ,  24.2       ,   5.2       ,  31.2       ,
#         57.        ,  14.2       ,  32.6       ,   4.8       ,
#         19.2       ,   5.4       ,   5.6       ,  35.        ,
#         12.6       ,  13.6       ,  28.2       ,   6.        ,
#          8.        ,   2.2       ,  40.8       ,   7.4       ,
# ...

# %%
df.nunique()
# Out:
# Longitude_            2
# Latitude              2
# Station_Name          1
# Climate_ID            4
# Date_Time          3652
# Year                 10
# Month                12
# Day                  31
# Max_Temp_           431
# Min_Temp_           415
# Mean_Temp_          425
# Heat_Deg_Days_      318
# Cool_Deg_Days_      100
# Total_Rain_         239
# Total_Snow_          67
# Total_Precip_       245
# Snow_on_Grnd_        37
# Dir_of_Max_Gust      37
# Spd_of_Max_Gust      49
# dtype: int64

# %% [markdown]
# 1. How has the average temperature in Windsor region changed over the past century? Is there a clear trend?

# %%
# Create a new dataframe with only the Windsor region data
windsor_df = df[df['Station_Name'].str.contains('WINDSOR')]

# Group by year and calculate the mean temperature
mean_temp_by_year = windsor_df.groupby('Year')['Mean_Temp_'].mean()

# Create a line plot of mean temperature by year with markers at value points
plt.plot(mean_temp_by_year.index, mean_temp_by_year, marker='o', label='Temperature (°C)')

# Set the x-axis tick labels to show all years
plt.xticks(mean_temp_by_year.index)
plt.xlabel('Year')
plt.ylabel('Mean Temperature (°C)')
plt.title('Mean Temperature in Windsor Region (2013-2022)', color='navy')
plt.tick_params(axis='both', which='major', labelsize=10)
plt.tight_layout()
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 2. How have extreme precipitation events (measured by total precipitation) in Windsor region changed over time?

# %%
# Filter the dataset to only include Windsor region data
windsor_df = df[df['Station_Name'].str.contains('WINDSOR')]

# Calculate the total precipitation by year
total_precip_by_year = windsor_df.groupby('Year')['Total_Precip_'].sum()

# Set the color palette
colors = sns.color_palette("Blues_r", len(total_precip_by_year))

# Create a bar plot of total precipitation by year
plt.bar(total_precip_by_year.index, total_precip_by_year, hatch = '/', label = 'Total Precip (mm)')
plt.xlabel('Year')
plt.ylabel('Total Precipitation (mm)')
plt.title('Total Precipitation in Windsor Region (2013-2022)')

# Customize plot
plt.xticks(total_precip_by_year.index, rotation=45)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(ticks=[0, 1000, 2000, 3000])
plt.tight_layout()
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 3. How has the mean temperature in Windsor region changed over the months with respect to the years, and what are the seasonal patterns in temperature?

# %%
# Filter the dataset to only include Windsor region data
windsor_df = df[df['Station_Name'].str.contains('WINDSOR')]

# Calculate the mean temperature by year and month
mean_temp_by_month = windsor_df.groupby(['Year', 'Month'])['Mean_Temp_'].mean().reset_index()

# Pivot the data to have years as rows and months as columns
pivot_mean_temp = mean_temp_by_month.pivot(index='Year', columns='Month', values='Mean_Temp_')

# Create a heatmap of mean temperature by year and month
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_mean_temp, cmap='coolwarm', annot=True, fmt=".1f", cbar_kws={'label': 'Mean Temperature (°C)'})
plt.title('Mean Temperature by Year and Month in Windsor Region (2013-2022)')
plt.show()

# %% [markdown]
# 4. How has the amount of snow in Windsor region varied over the years?

# %%
from matplotlib.ticker import MaxNLocator

# Filter the dataset to only include Windsor region data
windsor_df = df[df['Station_Name'].str.contains('WINDSOR')].dropna(subset=['Year', 'Month', 'Total_Snow_'])

# Convert the 'Year' column to integer
windsor_df['Year'] = windsor_df['Year'].astype(int)

# Set up the plot
fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(16, 20))
axs = axs.flatten()

# Iterate through each year from 2013 to 2022 and plot the data
for i, year in enumerate(range(2013, 2023)):
    if i < 10:
        ax = axs[i]
        ax = sns.lineplot(data=windsor_df[windsor_df['Year']==year], x='Month', y='Total_Snow_', ax=ax, color='red', linewidth=4, marker='o')
        ax.set_title(f"{year}")
        ax.set_xticks(range(1,13))
        ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
        ax.set_ylim(2.3, 4.1)
        ax.yaxis.set_major_locator(MaxNLocator(5))
        
# Remove extra subplots
for j in range(i+1, len(axs)):
    fig.delaxes(axs[j])

# Adjust the spacing between the subplots
plt.subplots_adjust(hspace=0.5, wspace=0.3)

# Set the title of the plot
plt.suptitle('Total Snowfall in Windsor Region by Year and Month', fontsize=20, y=0.93)

# Display the plot
plt.show()

# %% [markdown]
# 5. How has the maximum wind gust speed in Windsor region varied with mean temperature from the last 5 years?

# %%
# Replace '<31' values in 'Spd_of_Max_Gust' column with NaN
windsor_df['Spd_of_Max_Gust'] = windsor_df['Spd_of_Max_Gust'].replace('<31', np.nan)

# Convert 'Spd_of_Max_Gust' column to float64
windsor_df['Spd_of_Max_Gust'] = windsor_df['Spd_of_Max_Gust'].astype('float64')

# Filter data for the years 2018-2022
yearly_data = windsor_df[windsor_df['Year'].between(2018, 2022)].groupby('Year').agg({'Mean_Temp_': 'min', 'Spd_of_Max_Gust': 'max'}).reset_index()

# Create a bubble plot
fig, ax = plt.subplots(figsize=(8, 6))
sc = ax.scatter(yearly_data['Mean_Temp_'], yearly_data['Spd_of_Max_Gust'], s=yearly_data['Year']*2.5, alpha=0.5, c=yearly_data['Year'], cmap='cool')
plt.xlim(yearly_data['Mean_Temp_'].min() - 1, yearly_data['Mean_Temp_'].max() + 1)
plt.ylim(yearly_data['Spd_of_Max_Gust'].min() - 10, yearly_data['Spd_of_Max_Gust'].max() + 10)
plt.xlabel('Mean Temperature (°C)')
plt.ylabel('Maximum Wind Gust Speed (km/h)')
plt.title('Maximum Wind Gust Speed vs. Mean Temperature for the last 5 years in Windsor Region (2018-2022)')

# Add annotation to each data point
for i, year in enumerate(yearly_data['Year']):
    plt.annotate(int(year), (yearly_data['Mean_Temp_'][i], yearly_data['Spd_of_Max_Gust'][i]), ha='center')

# Create legend
handles, labels = sc.legend_elements(prop='colors', alpha=0.5)
legend1 = ax.legend(handles, yearly_data['Year'].astype(int), title='Year', loc='upper left', bbox_to_anchor=(1, 1), markerscale=1.2)

# Add legend to the plot
ax.add_artist(legend1)

# Display grid
ax.grid(True)

plt.show()
